# %% [markdown]
# # Homework 7
#
# Rixin Li & G . Besla
#
# Filled out by Colton Quirk

# %%
# import necessary modules
# numpy provides powerful multi-dimensional arrays to hold and manipulate data
import numpy as np
# matplotlib provides powerful functions for plotting figures
import matplotlib.pyplot as plt
# astropy provides unit system and constants for astronomical calculations
import astropy.units as u
import astropy.constants as const
# import Latex module so we can display the results with symbols
from IPython.display import Latex
from tqdm import tqdm
# %matplotlib inline

# import CenterOfMass to determine the COM pos/vel of M33
from CenterOfMass import CenterOfMass

# import the GalaxyMass to determine the mass of M31 for each component
from GalaxyMass import ComponentMass

# %% [markdown]
# # M33AnalyticOrbit

# %%
class M33AnalyticOrbit:
    """ Calculate the analytical orbit of M33 around M31 """
    
    def __init__(self, filename):
        """
        Initialize function for the analytical orbit class

        Inputs: filename, name of the file to store the orbit.
        """
        # get the gravitational constant (the value is 4.498502151575286e-06)
        self.G = const.G.to(u.kpc**3/u.Msun/u.Gyr**2).value
        
        ### Store the output file name
        self.filename = filename

        # get the current pos/vel of M33
        pos_M33, vel_M33 = self._compute_COM("M33_000.txt", volDec=4)

        # get the current pos/vel of M31 
        pos_M31, vel_M31 = self._compute_COM("M31_000.txt")

        ### store the DIFFERENCE between the vectors posM33 - posM31
        # create two VECTORs self.r0 and self.v0 and have them be the
        # relative position and velocity VECTORS of M33
        self.r0 = pos_M33 - pos_M31
        self.v0 = vel_M33 - vel_M31
           
        ### get the mass of each component in M31 
        ### disk
        # self.rdisk = scale length (no units)
        self.rdisk = 5 # kpc

        # self.Mdisk set with ComponentMass function. Remember to *1e12 to get the right units. Use the right ptype
        self.Mdisk = ComponentMass('M31_000.txt', 2)*1e12 # ptype=2 are disk particles
        
        ### bulge
        # self.rbulge = set scale length (no units)
        self.rbulge = 1 # kpc

        # self.Mbulge  set with ComponentMass function. Remember to *1e12 to get the right units Use the right ptype
        self.Mbulge = ComponentMass('M31_000.txt', 3)*1e12 # ptype=3 are bulge particles
        
        # Halo
        # self.rhalo = set scale length from HW5 (no units)
        self.rhalo = 61.60 # kpc from Assignment 5

        # self.Mhalo set with ComponentMass function. Remember to *1e12 to get the right units. Use the right ptype
        self.Mhalo = ComponentMass('M31_000.txt', 1)*1e12 # ptype=1 are halo particles

    
    def _compute_COM(self, filename, ptype=2, delta=0.1, volDec=2):
        """
        Helper function to calculate the position and velocity
        of the Center of Mass of a galaxy.

        Inputs:
            filename: 'str'
                        The name of the file to read the particle information from
            ptype: 'int'
                    Specify the particle type to calculate the center of mass of
                    1: Halo particles
                    2: Disk particles
                    3: Bulge Particles
            delta: 'float'
                    Center of Mass precision limit
            volDec: 'float'
                    How much to decrement the volume per iteration in COM

        Ouptuts:
            pos: 'array'
                  Center of Mass position of the galaxy
            vel: 'array'
                  Center of Mass velocity of the galaxy
        """
        # Create a CenterOfMass Object for the galaxy using the specified
        # particle type
        COM = CenterOfMass(filename, ptype)
        # Determine the position of the center of mass
        pos = COM.COM_P(delta=delta, volDec=volDec)
        # Determine the velocity of the center of mass
        vel = COM.COM_V(*pos)
        # Return the pos and vel arrays, get rid of astropy units with .value
        return pos.value, vel.value

    
    def HernquistAccel(self, M, r_a, r):
        """
        Function to compute the gravitational acceleration induced by a Hernquist profile.
        This will be used for the acceleration due to the Bulge and Halo particles

        inputs:
            M: float
                Mass of something, Msun
            r_a: float
                Hernquist scale length, kpc
            r: vector
                Position vector of the gravitationally influenced object, kpc

        outputs:
            Hern: vector
                acceleration vector induced by the hernquist profile mass
        """
        
        ### Store the magnitude of the position vector
        r_mag = np.linalg.norm(r)
        
        ### Store the Acceleration
        Hern =  -r*self.G*M/(r_mag*(r_a+r_mag)**2) #The formula in the HW instructions
        
        return Hern

    
    def MiyamotoNagaiAccel(self, M, r_d, r):
        """
        Function to compute the acceleration from the disk at far distances.
        This function uses the profile from Miyamoto-Nagai 1975.
        This will be used for the acceleration due to the disk particles

        Inputs:
            M: float
                Disk Mass, Msun
            r_d: float
                disk scale length, kpc
            r: vector
                position vector of the acceleratee

        Outputs:
            accel: vector
                gravitational acceleration vector
        """
        # Unpack the x, y, and z components of the r vector
        x, y, z = r
        # Store z_d
        z_d = r_d/5.0

        # Store the R and B values needed for the calculation
        R = np.sqrt(x*x + y*y)
        B = r_d + np.sqrt(z*z + z_d*z_d)

        # Store the z correction array 
        corr = np.array([1, 1, B/np.sqrt(z*z + z_d*z_d)])

        # Calculate the acceleration
        accel = -r*corr*self.G*M/(R*R + B*B)**1.5

        return accel

    
    def M31Accel(self, r):
        """
        Function to compute the total acceleration from M31, from the disk
            bulge, and halo particles.

        Inputs:
            r: vector
                current position vector of M33

        Outputs:
            totalAccel: vector
                Total acceleration of M33 due to M31
        """
        # Calculate the acceleration due to the various components of M31
        accelHalo = self.HernquistAccel(self.Mhalo, self.rhalo, r)
        accelBulge = self.HernquistAccel(self.Mbulge, self.rbulge, r)
        accelDisk = self.MiyamotoNagaiAccel(self.Mdisk, self.rdisk, r)
            
        # return the SUM of the output of the acceleration functions - this will return a VECTOR 
        return accelHalo + accelBulge + accelDisk

        
    def LeapFrog(self, dt, r, v):
        """
        Function to compute the next step in the LeapFrog integration algorithm.

        Inputs:
            dt: float
                size of timestep
            r: vector
                current position vector
            v: vector
                current velocity vector

        Outputs:
            rnew: vector
                position vector for the next step
            vnew: vector
                velocity vector for the next step
        """
        
        # predict the position at the next half timestep
        rhalf = r + 0.5 * dt * v
        
        # predict the final velocity at the next timestep using the acceleration field at the rhalf position
        vnew = v + self.M31Accel(rhalf) * dt
        
        # predict the final position using the average of the current velocity and the final velocity
        # this accounts for the fact that we don't know how the speed changes from the current timestep to the 
        # next, so we approximate it using the average expected speed over the time interval dt. 
        rnew = rhalf + 0.5 * dt * vnew
        
        return rnew, vnew # return the new position and velocity vectors
    
    
    def OrbitIntegrator(self, t0, dt, tmax):
        """
        Function which integrates the orbit of M33 over time.

        Inputs:
            t0: float
                start time of the orbit
           dt: float
               timestep
           tmax: float
               end time of the simulation

        Outputs:
           Saves the orbit in a file
           Does not return a value
        """
        # Create an array of all time values from t0 to tmax using the 
        # time interval dt
        t_vals = np.arange(t0, tmax, dt)
        
        # Create an array of zeros with the same number of rows as t_vals has values
        # and 7 columns to store data for each timestep
        orbit = np.zeros((t_vals.shape[0], 7))

        # Start the simulation at the initial position and velocity
        r = self.r0
        v = self.v0
        for i, t in enumerate(tqdm(t_vals)):
            # store the current values of time, position, and velocity
            orbit[i] = t, *r, *v

            # update the position and velocity using the leapfrog integration technique
            r, v = self.LeapFrog(dt, r, v)

        # write the data to a file
        np.savetxt(self.filename, orbit, fmt = "%11.3f"*7, comments='#', 
               header="{:>10s}{:>11s}{:>11s}{:>11s}{:>11s}{:>11s}{:>11s}"\
               .format('t', 'x', 'y', 'z', 'vx', 'vy', 'vz'))
        
        # there is no return function

# %%
# Name of the file to store the Numerically Integrated
# orbit of M33
outfile = "M33OrbitAna.txt"

# %%
# Create an M33NalayticOrbit object with that output file
Orbit = M33AnalyticOrbit(filename=outfile)

# %%
# Calculate the orbit of M33 from 0 Gyr to 10Gyr
t0 = 0 # Gyr
tmax = 10 # Gyr
dt = 1e-4 # Gyr
Orbit.OrbitIntegrator(t0=t0, dt=dt, tmax=tmax)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 100000/100000 [00:03<00:00, 25611.42it/s]

# %%
# Load the data from the output file
OrbitAna = np.genfromtxt(outfile, names=True)

# %%
# Calculate the magnitude of the relative position and velocity vectors between M31 and M33
r_mag = np.sqrt(OrbitAna['x']**2 + OrbitAna['y']**2 + OrbitAna['z']**2)
v_mag = np.sqrt(OrbitAna['vx']**2 + OrbitAna['vy']**2 + OrbitAna['vz']**2)

# %%
# Separation and Relative Velocity from Homework 6
orbit_M31 = np.genfromtxt('Orbit_M31.txt', names=True)
orbit_M33 = np.genfromtxt('Orbit_M33.txt', names=True)

orbit_M31_pos = np.column_stack((orbit_M31['x'], orbit_M31['y'], orbit_M31['z']))
orbit_M31_vel = np.column_stack((orbit_M31['vx'], orbit_M31['vy'], orbit_M31['vz']))

orbit_M33_pos = np.column_stack((orbit_M33['x'], orbit_M33['y'], orbit_M33['z']))
orbit_M33_vel = np.column_stack((orbit_M33['vx'], orbit_M33['vy'], orbit_M33['vz']))

sep_M31_M33 = np.linalg.norm(orbit_M31_pos - orbit_M33_pos, axis=1)
vel_M31_M33 = np.linalg.norm(orbit_M31_vel - orbit_M33_vel, axis=1)

# %% [markdown]
# # Questions

# %% [markdown]
# ## 1. Plot the Separation and Relative Velocities

# %%
fig, ax = plt.subplots(2, 1, figsize=(12, 9), layout='constrained')
ax[0].plot(orbit_M31['t'], sep_M31_M33, color='k', label='Simulated Separation')
ax[0].plot(OrbitAna['t'], r_mag, color='r', linestyle='--', label='Integrated Separation')
ax[0].set_ylabel('Separation (kpc)')
ax[0].set_title('M31 and M33 Separation')
ax[0].axvline(1, label=r'Plots Diverge $1Gyr$')
ax[0].legend()

ax[1].plot(orbit_M31['t'], vel_M31_M33, color='k', label='Simulated Relative Velocity')
ax[1].plot(OrbitAna['t'], v_mag, color='r', linestyle='--', label='Integrated Relative Velocity')
ax[1].set_ylabel('Relative Velocity (km/s)')
ax[1].set_xlabel('Time (Gyr)')
ax[1].set_title('M31 and M33 Relative Velocity')
ax[1].axvline(1, label=r'Plots Diverge $1Gyr$')
ax[1].legend()
plt.show()

# %% [markdown]
# ## 2. How do the plots compare?

# %% [markdown]
# The plots of separation and velocity for the integrated velocity we calculated in this homework and the simulated values found in Homework 6 follow the same trajectory until aproximately $1Gyr$ and then diverge.

# %% [markdown]
# ## 3. What missing physics could make the difference?

# %% [markdown]
# The assumptions in the acceleration calculations are that the particles are acting as a single point mass. This ignores the effects of dynamical friction. The point masses will just move past each other acting according to the gravitational forces between them. However with extended sources, or sources with many particles associated with them, as they move past each other the center of masses will be impacted more as the particles interact with the other particles closer to them. This leads to the faster decay within the simulated M31 and M33 separation rather than our integrated values.

# %% [markdown]
# ## 4. The MW is missing in these calculates. How might you include its effects?

# %% [markdown]
# By incorporating the masses of its various components in the total acceleration function. You would do the same thing with the MW as was done with M31 and then add all the accelerations together.
